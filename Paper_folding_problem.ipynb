# %%
# Paper folding problem
# Problem 1 Implementation using exponentiation arithmetic operators
#Code to calculate the thickness when the paper is folded once

THICKNESS = 0.00008
folded_thickness = THICKNESS * (2 ** 42)
print("Thickness #1: {} meters".format(folded_thickness))

# Problem 2 - Unit Conversion
# Convert meters to kilometers and display with two decimal places

print("Thickness #1 in Km: {: .2f} kilometers".format(folded_thickness / 1000))
# Problem 3 - Create using a for statement

folded_thickness = 0.00008
for i in range(1, 43, 1):
    folded_thickness = folded_thickness * 2
print("Thickness #2: {: .2f} kilometers".format(folded_thickness / 1000))

# Problem 4 - Comparison of calculation time

import time
start = time.time()
#————————
THICKNESS = 0.00008
folded_thickness = THICKNESS * (2 ** 42)
print("Thickness #1: {} kilometers".format(folded_thickness / 1000))
#————————
elapsed_time = time.time() - start
print("time #1 : {}[s]".format(elapsed_time))

start = time.time()
#————————

folded_thickness = 0.00008
for i in range(1, 43, 1):
    folded_thickness = folded_thickness * 2
print("Thickness #2: {: .2f} kilometers".format(folded_thickness / 1000))
#————————
elapsed_time = time.time() - start
print("time #2 : {}[s]".format(elapsed_time))

# %timeit pass
#####
#————————
THICKNESS = 0.00008
folded_thickness = THICKNESS * (2 ** 42)
print("Thickness #1: {} kilometers".format(folded_thickness / 1000))
#————————
#####
# %timeit pass
#####
#————————
folded_thickness = 0.00008
for i in range(1, 43, 1):
    folded_thickness = folded_thickness * 2
print("Thickness #2: {: .2f} kilometers".format(folded_thickness / 1000))
#————————
#####

# Problem 5 - Saving to a list

thickness = []
folded_thickness = 0.00008
for i in range(1, 43, 1):
    folded_thickness = folded_thickness * 2
    thickness.append(folded_thickness)
print(thickness)
len(thickness)

# Problem 6 Displaying a line graph

import matplotlib.pyplot as plt
# Display the graph. Title and axis label name.

plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(thickness) # Enter the variable name of the list in "List name"
plt.show()
# Problem 7 Customizing graphs
# Display a red line graph.

plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(thickness, color = 'red')
plt.show()

plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness[m]")
plt.tick_params(labelsize=20) # Make settings related to axis values
plt.plot(thickness)
plt.show()

plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness[m]")
plt.plot(thickness, color = 'black')
plt.show()
# Out:
# Thickness #1: 351843720.88832 meters
# Thickness #1 in Km:  351843.72 kilometers
# Thickness #2:  351843.72 kilometers
# Thickness #1: 351843.72088832 kilometers
# time #1 : 0.0[s]
# Thickness #2:  351843.72 kilometers
# time #2 : 0.0[s]
# 8.44 ns ± 0.461 ns per loop (mean ± std. dev. of 7 runs, 100,000,000 loops each)
# Thickness #1: 351843.72088832 kilometers
# 7.58 ns ± 0.148 ns per loop (mean ± std. dev. of 7 runs, 100,000,000 loops each)
# Thickness #2:  351843.72 kilometers
# [0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024, 0.02048, 0.04096, 0.08192, 0.16384, 0.32768, 0.65536, 1.31072, 2.62144, 5.24288, 10.48576, 20.97152, 41.94304, 83.88608, 167.77216, 335.54432, 671.08864, 1342.17728, 2684.35456, 5368.70912, 10737.41824, 21474.83648, 42949.67296, 85899.34592, 171798.69184, 343597.38368, 687194.76736, 1374389.53472, 2748779.06944, 5497558.13888, 10995116.27776, 21990232.55552, 43980465.11104, 87960930.22208, 175921860.44416, 351843720.88832]
